# %%
using DataFrames, FileIO, DelimitedFiles
using Plots, Optim, LsqFit

# %%
# Get ready
home = "/home/pbarletta/labo/20/cph_obp/"
dir_eol_rmsf = string(home, "run/eol/rmsf/")

nstlim = 19500
aa = 113
phs = collect(30:5:75)
idx = collect(1:10)
pdt_steps = collect(0:1:7)
titrable_cnt = 36
titrable_resis = [4, 5, 7, 11, 13, 18, 20, 24, 27, 30, 33, 37, 39,
    40, 41, 42, 48, 52, 58, 59, 64, 69, 73, 77, 78, 82, 87, 93, 94,
    97, 99, 102, 109, 111, 114, 117];
titrable_resnames = ["GL4", "GL4", "LYS", "HIP", "GL4", "LYS", "GL4", "AS4", "LYS",
    "AS4", "GL4", "AS4", "GL4", "AS4", "LYS", "LYS", "GL4", "LYS",
    "AS4", "LYS", "LYS", "LYS", "GL4", "AS4", "GL4", "LYS", "AS4",
    "GL4", "GL4", "HIP", "LYS", "LYS", "LYS", "LYS", "LYS", "AS4"];

# %%
for i in 1:10
    global rmsf_eol_idx = readdlm(joinpath(dir_eol_rmsf, string(i),
            string("rmsf_eol_", idx[i])))[2:end, 2]
    global rmsf_eol_ph = readdlm(joinpath(dir_eol_rmsf, string(phs[i], "ph"),
            string("rmsf_eol_", phs[i])))[2:end, 2]

    sym_rmsf_eol_idx = Symbol("rmsf_eol_", idx[i])
    sym_rmsf_eol_ph = Symbol("rmsf_eol_", phs[i])
    eval(:($sym_rmsf_eol_idx = rmsf_eol_idx))
    eval(:($sym_rmsf_eol_ph = rmsf_eol_ph))
end

# %% [markdown]
# ## RMSF por pH

# %%
plot(collect(1:aa), rmsf_eol_30,
        title = string("RMSF - pH = ", 30), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_35,
        title = string("RMSF - pH = ", 35), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_40,
        title = string("RMSF - pH = ", 40), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_45,
        title = string("RMSF - pH = ", 45), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_50,
        title = string("RMSF - pH = ", 50), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_55,
        title = string("RMSF - pH = ", 55), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_60,
        title = string("RMSF - pH = ", 60), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_65,
        title = string("RMSF - pH = ", 65), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_70,
        title = string("RMSF - pH = ", 70), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_75,
        title = string("RMSF - pH = ", 75), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %% [markdown]
# ## RMSF por idx

# %%
plot(collect(1:aa), rmsf_eol_1, 
        title = string("RMSF - idx = ", 1), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_2, 
        title = string("RMSF - idx = ", 2), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_3, 
        title = string("RMSF - idx = ", 3), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_4, 
        title = string("RMSF - idx = ", 4), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_5, 
        title = string("RMSF - idx = ", 5), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_6, 
        title = string("RMSF - idx = ", 6), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_7, 
        title = string("RMSF - idx = ", 7), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_8, 
        title = string("RMSF - idx = ", 8), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_9, 
        title = string("RMSF - idx = ", 9), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")

# %%
plot(collect(1:aa), rmsf_eol_10, 
        title = string("RMSF - idx = ", 10), size = (750, 400), label = false,
        xticks = collect(5:10:aa), yaxis = "RMSF [A]", xaxis = "Residue #")
